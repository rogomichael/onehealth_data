# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("m3train.xlsx")
df
# Out:
#       Region  Year  label  max_temp_q1  max_temp_q2  max_temp_q3  max_temp_q4  \
# 0      AL011  2006      0     8.764677    19.652742    25.863468    21.958666
# 1      AL012  2006      0          NaN          NaN          NaN          NaN
# 2      AL013  2006      0     6.686613    18.338387    24.337822    20.370749
# 3      AL014  2006      0    11.325645    22.615564    29.519193    25.198666
# 4      AL015  2006      0     9.695419    21.285612    28.166128    23.695000
# ...      ...   ...    ...          ...          ...          ...          ...
# 37767  DE11A  2021      0     7.696666    15.441290    25.153333    21.535999
# 37768  ITH31  2021      1    10.203724    21.404239    30.380737    26.349142
# 37769  PL431  2021      1     4.377474    17.407212    26.232524    20.355380
# 37770  UKM72  2021      0     6.357411    11.961774    19.822016    17.757166
# 37771  TR310  2021      0          NaN          NaN          NaN          NaN
#
# ...

# %%
new_test_df = df.replace(np.nan, -999)
new_test_df
# Out:
#          0           1           2           3           4           5   \
# 0     AL022   17.579311    5.304295   22.848726  656.578553   29.960000
# 1     AT124   11.866204    6.745591   26.583715  702.105564   24.302998
# 2     AT127   14.304366    6.782100   26.136153  738.614454   27.227499
# 3     AT130 -999.000000 -999.000000 -999.000000 -999.000000 -999.000000
# 4     AT130 -999.000000 -999.000000 -999.000000 -999.000000 -999.000000
# ...     ...         ...         ...         ...         ...         ...
# 1195  UKN07   12.317430    4.322916   23.915483  427.975250   21.486666
# 1196  UKN07   12.317430    4.322916   23.915483  427.975250   21.486666
# 1197  UKN0B   12.165224    4.513552   25.155176  415.534325   21.317999
# 1198  UKN0F -999.000000 -999.000000 -999.000000 -999.000000 -999.000000
# 1199  UKN16 -999.000000 -999.000000 -999.000000 -999.000000 -999.000000
#
#               6           7           8           9           10          11  \
# ...

# %%
new_test_df.to_excel("new_m2test_biovars_999.xlsx", index=False)

# %% [markdown]
# # Mtrain

# %%
mtrain = pd.read_excel("new_m2train_biovars.xlsx", header=None)
mtrain99 = mtrain.replace(np.nan, -999)

# %%
mtrain99.to_excel("new_m2train_biovars_999.xlsx", index=False)
